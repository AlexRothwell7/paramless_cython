# %%
# %pylab inline
from scipy.integrate import simps
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from JSAnimation.IPython_display import display_animation

# %%
import pyximport; pyximport.install()
import paramless_fast as pmain
import paramless_cython as pm

# %% [markdown]
# #Evolution of seasonal flowering strategies

# %% [markdown]
# Here I test the function simulation framework with the example of section 7  in Dieckmann et al. JTB (2006). It analyzes the evolution of seasonal flowering schedules.

# %% [markdown]
# We will evolve a function $x(a)$, where $a \in [0,1]$ (s.t $x(a) > 0 \forall a$  and $\int x(a) da = 1$)

# %% [markdown]
# ##Define fitness and mutations

# %% [markdown]
# We start by defining a mutation that *does not* allow negative values and *preserves the area under the surface* by compensating all perturbances,therby complying with the restriction $\int x(a) da = 1 $ (using: **gaussian_mutation_distribution**)

# %% [markdown]
# $x(a)$ denotes the ammount of flowers produced at time $t$. We normalize $t$ to be between zero and one. Thus domain of $x(\cdot)$ is $(0,1)$.

# %%
domain = np.arange(0.001, 1.0, 0.01)

# %%
class FloweringFitness(pm.FitnessFunction):
    def __init__(self, domain, alpha, beta):
        self.domain = domain
        self.alpha = alpha
        self.beta = beta
        
    def get(self, resident, mutant):
        pass

# %% [markdown]
# We first define the probability of setting seed $p_x(\cdot)$, as follows:

# %%
#alpha, beta, k_function

# %%
def p_x(self, a, x, k):
    #takes a, and functions x and k
    return math.e**(-x[a]/k(a))

FloweringFitness.p_x = p_x

# %% [markdown]
# In the example, function $k(\cdot)$ is a time-dependent carrying capacity, given by $K(a)= 100(2 + \sin2 \pi ((a-1)^2 - \frac{1}{4}))$

# %%
def k(self, a):
    return 100*(2 + math.sin(2*math.pi*((a-1.0)**2.0 - 0.25)))

FloweringFitness.k_function = k

# %%
plot(domain, [k(None,a) for a in domain], label = 'K(a)')
plt.legend(loc='best')
plt.title(r'Carrying capacity $K(a)$')
plt.ylim((99, 305))
plt.xlabel('time')

# %% [markdown]
# We also consider a function $c(e)$, which denotes the factor in which competition affects the schedule of a competing individual. Here $e$, which is a function of a is the mutant's excess flowering. It is assumed that
#
# $c(e(a)) = 2 / (1 + \exp(-\alpha e(a)))$
#
#
# $\alpha$ determines the strenght of the asymmetric competition between mutant and resident.

# %%
def c(self, e, alpha):
    return 2.0/(1 + math.e**(-alpha*e))

FloweringFitness.c = c

# %% [markdown]
# The birth-rate of a a rare mutant with schedule $x'$ is given by:
#
# $b(x',x) = \int x'(a)c([x'(a)-x(a)]/x(a)^{\beta})p_x (a)da $
#
# Here $\beta$ measures the excess flowering intensity.

# %%
def birth(self, x_mutant, x_resident, domain, alpha, beta, k_function):
    x_resident_dict = dict(zip(domain, x_resident))
    x_mutant_dict = dict(zip(domain, x_mutant))
    integrand = [x_mutant_dict[a]*self.c((x_mutant_dict[a]-x_resident_dict[a])/(x_mutant_dict[a]**beta), alpha)*self.p_x(a, x_resident_dict, k_function) for a in domain]
    return simps(integrand, domain)

FloweringFitness.birth = birth

# %% [markdown]
# Since death rates are assume to be constant, we can define fitness solely in terms of birth rates:

# %%
def flowering_fitness(self, resident, mutant):
    fitness_resident = self.birth(resident, resident, self.domain, self.alpha, self.beta, self.k_function)
    fitness_mutant = self.birth(mutant, resident, self.domain, self.alpha, self.beta, self.k_function)
    return fitness_resident, fitness_mutant

FloweringFitness.get = flowering_fitness

# %%
initial_surface = np.ones_like(domain)

# %%
number_of_generations = 5000

# %%
# %%capture
seed = 777

fitness_function = FloweringFitness(domain, 1.0, 0.9)
mutator = pm.GaussianDistributionMutator(0.01, domain, 0.05)
evolver = pm.StandardEvolver(fitness_function, mutator)
pm.setup(seed)

ans, series = pmain.evolve(initial_surface, evolver,
                     iterations=number_of_generations,
                     return_time_series=True, seed=seed)

# %%
plot(domain, ans)

# %%
simps(ans, domain)
# Out:
# 1.1599634947645046

# %%
ani = pmain.create_video_from_time_series(series, None, domain, filename='/home/alex/workspace/out.mp4', approximate_number_of_frames=1000, record_every=50)
display_animation(ani)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgQVAIEAHLZOOYUIGZ">
#     <br>
#     <input id="_anim_sliderQVAIEAHLZOOYUIGZ" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animQVAIEAHLZOOYUIGZ.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animQVAIEAHLZOOYUIGZ.slower()">&#8211;</button>
#     <button onclick="animQVAIEAHLZOOYUIGZ.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animQVAIEAHLZOOYUIGZ.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animQVAIEAHLZOOYUIGZ.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animQVAIEAHLZOOYUIGZ.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animQVAIEAHLZOOYUIGZ.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animQVAIEAHLZOOYUIGZ.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animQVAIEAHLZOOYUIGZ.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animQVAIEAHLZOOYUIGZ.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectQVAIEAHLZOOYUIGZ" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgQVAIEAHLZOOYUIGZ";
#     var slider_id = "_anim_sliderQVAIEAHLZOOYUIGZ";
#     var loop_select_id = "_anim_loop_selectQVAIEAHLZOOYUIGZ";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#
#
#     /* set a timeout to make sure all the above elements are created before
#        the object is initialized. */
#     setTimeout(function() {
#         animQVAIEAHLZOOYUIGZ = new Animation(frames, img_id, slider_id, 1, loop_select_id);
#     }, 0);
#   })()
# </script>
